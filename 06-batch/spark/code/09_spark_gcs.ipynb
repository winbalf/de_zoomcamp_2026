# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.conf import SparkConf
from pyspark.context import SparkContext

# %%
credentials_location = '/home/alexey/.google/credentials/google_credentials.json'

conf = SparkConf() \
    .setMaster('local[*]') \
    .setAppName('test') \
    .set("spark.jars", "./lib/gcs-connector-hadoop3-2.2.5.jar") \
    .set("spark.hadoop.google.cloud.auth.service.account.enable", "true") \
    .set("spark.hadoop.google.cloud.auth.service.account.json.keyfile", credentials_location)

# %%
sc = SparkContext(conf=conf)

hadoop_conf = sc._jsc.hadoopConfiguration()

hadoop_conf.set("fs.AbstractFileSystem.gs.impl",  "com.google.cloud.hadoop.fs.gcs.GoogleHadoopFS")
hadoop_conf.set("fs.gs.impl", "com.google.cloud.hadoop.fs.gcs.GoogleHadoopFileSystem")
hadoop_conf.set("fs.gs.auth.service.account.json.keyfile", credentials_location)
hadoop_conf.set("fs.gs.auth.service.account.enable", "true")
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/03/10 20:17:16 WARN Utils: Your hostname, LAPTOP-AABVIV1G, resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 26/03/10 20:17:16 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 26/03/10 20:17:17 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/03/10 20:17:17 WARN DependencyUtils: Local jar /home/ehbuenoa/DataTalksClub/de_zoomcamp_2026/06-batch/spark/code/lib/gcs-connector-hadoop3-2.2.5.jar does not exist, skipping.
# 26/03/10 20:17:17 INFO SparkContext: Running Spark version 4.1.1
# 26/03/10 20:17:17 INFO SparkContext: OS info Linux, 6.6.87.2-microsoft-standard-WSL2, amd64
# 26/03/10 20:17:17 INFO SparkContext: Java version 17.0.18+8-Ubuntu-122.04.1
# 26/03/10 20:17:17 INFO ResourceUtils: ==============================================================
# 26/03/10 20:17:17 INFO ResourceUtils: No custom resources configured for spark.driver.
# 26/03/10 20:17:17 INFO ResourceUtils: ==============================================================
# 26/03/10 20:17:17 INFO SparkContext: Submitted application: test
# 26/03/10 20:17:17 INFO SecurityManager: Changing view acls to: ehbuenoa
# 26/03/10 20:17:17 INFO SecurityManager: Changing modify acls to: ehbuenoa
# 26/03/10 20:17:17 INFO SecurityManager: Changing view acls groups to: ehbuenoa
# 26/03/10 20:17:17 INFO SecurityManager: Changing modify acls groups to: ehbuenoa
# 26/03/10 20:17:17 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users with view permissions: ehbuenoa groups with view permissions: EMPTY; users with modify permissions: ehbuenoa; groups with modify permissions: EMPTY; RPC SSL disabled
# 26/03/10 20:17:18 INFO Utils: Successfully started service 'sparkDriver' on port 36631.
# 26/03/10 20:17:18 INFO SparkEnv: Registering MapOutputTracker
# 26/03/10 20:17:18 INFO SparkEnv: Registering BlockManagerMaster
# 26/03/10 20:17:18 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 26/03/10 20:17:18 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 26/03/10 20:17:18 INFO SparkEnv: Registering BlockManagerMasterHeartbeat
# 26/03/10 20:17:18 INFO DiskBlockManager: Created local directory at /tmp/blockmgr-e76fe508-5aaf-4c2d-9568-139d26f53938
# 26/03/10 20:17:18 INFO SparkEnv: Registering OutputCommitCoordinator
# 26/03/10 20:17:18 INFO JettyUtils: Start Jetty 0.0.0.0:4040 for SparkUI
# 26/03/10 20:17:18 INFO Utils: Successfully started service 'SparkUI' on port 4040.
# 26/03/10 20:17:18 ERROR SparkContext: Failed to add ./lib/gcs-connector-hadoop3-2.2.5.jar to Spark environment
# java.io.FileNotFoundException: Jar /home/ehbuenoa/DataTalksClub/de_zoomcamp_2026/06-batch/spark/code/lib/gcs-connector-hadoop3-2.2.5.jar not found
# 	at org.apache.spark.SparkContext.addLocalJarFile$1(SparkContext.scala:2185)
# 	at org.apache.spark.SparkContext.addJar(SparkContext.scala:2241)
# 	at org.apache.spark.SparkContext.$anonfun$new$16(SparkContext.scala:544)
# 	at org.apache.spark.SparkContext.$anonfun$new$16$adapted(SparkContext.scala:544)
# 	at scala.collection.IterableOnceOps.foreach(IterableOnce.scala:630)
# 	at scala.collection.IterableOnceOps.foreach$(IterableOnce.scala:628)
# 	at scala.collection.AbstractIterable.foreach(Iterable.scala:936)
# 	at org.apache.spark.SparkContext.<init>(SparkContext.scala:544)
# 	at org.apache.spark.api.java.JavaSparkContext.<init>(JavaSparkContext.scala:59)
# 	at java.base/jdk.internal.reflect.NativeConstructorAccessorImpl.newInstance0(Native Method)
# 	at java.base/jdk.internal.reflect.NativeConstructorAccessorImpl.newInstance(NativeConstructorAccessorImpl.java:77)
# 	at java.base/jdk.internal.reflect.DelegatingConstructorAccessorImpl.newInstance(DelegatingConstructorAccessorImpl.java:45)
# 	at java.base/java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:500)
# 	at java.base/java.lang.reflect.Constructor.newInstance(Constructor.java:481)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:247)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)
# 	at py4j.Gateway.invoke(Gateway.java:238)
# 	at py4j.commands.ConstructorCommand.invokeConstructor(ConstructorCommand.java:80)
# 	at py4j.commands.ConstructorCommand.execute(ConstructorCommand.java:69)
# 	at py4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:184)
# 	at py4j.ClientServerConnection.run(ClientServerConnection.java:108)
# 	at java.base/java.lang.Thread.run(Thread.java:840)
# 26/03/10 20:17:18 INFO ResourceProfile: Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 1, script: , vendor: , memory -> name: memory, amount: 1024, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
# 26/03/10 20:17:18 INFO ResourceProfile: Limiting resource is cpu
# 26/03/10 20:17:18 INFO ResourceProfileManager: Added ResourceProfile id: 0
# 26/03/10 20:17:18 INFO SecurityManager: Changing view acls to: ehbuenoa
# 26/03/10 20:17:18 INFO SecurityManager: Changing modify acls to: ehbuenoa
# 26/03/10 20:17:18 INFO SecurityManager: Changing view acls groups to: ehbuenoa
# 26/03/10 20:17:18 INFO SecurityManager: Changing modify acls groups to: ehbuenoa
# 26/03/10 20:17:18 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users with view permissions: ehbuenoa groups with view permissions: EMPTY; users with modify permissions: ehbuenoa; groups with modify permissions: EMPTY; RPC SSL disabled
# 26/03/10 20:17:18 INFO Executor: Starting executor ID driver on host 10.255.255.254
# 26/03/10 20:17:18 INFO Executor: OS info Linux, 6.6.87.2-microsoft-standard-WSL2, amd64
# 26/03/10 20:17:18 INFO Executor: Java version 17.0.18+8-Ubuntu-122.04.1
# 26/03/10 20:17:18 INFO Executor: Starting executor with user classpath (userClassPathFirst = false): ''
# 26/03/10 20:17:18 INFO Executor: Created or updated repl class loader org.apache.spark.util.MutableURLClassLoader@505e9b84 for default.
# 26/03/10 20:17:18 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 46105.
# 26/03/10 20:17:18 INFO NettyBlockTransferService: Server created on 10.255.255.254:46105
# 26/03/10 20:17:18 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 26/03/10 20:17:18 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 10.255.255.254, 46105, None)
# 26/03/10 20:17:18 INFO BlockManagerMasterEndpoint: Registering block manager 10.255.255.254:46105 with 434.4 MiB RAM, BlockManagerId(driver, 10.255.255.254, 46105, None)
# 26/03/10 20:17:18 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 10.255.255.254, 46105, None)
# 26/03/10 20:17:18 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, 10.255.255.254, 46105, None)

# %%
spark = SparkSession.builder \
    .config(conf=sc.getConf()) \
    .getOrCreate()

# %%
df_green = spark.read.parquet('gs://dtc_data_lake_de-zoomcamp-nytaxi/pq/green/*/*')

# %%
df_green.count()
# Out:
# 2304517
